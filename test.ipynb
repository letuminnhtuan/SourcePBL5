# %%
import DetectPlate.function.utils_rotate as utils_rotate
import cv2
import matplotlib.pyplot as plt

# %%
rc_image = cv2.imread("crop.jpg")
plt.imshow(utils_rotate.deskew(rc_image, 0, 0))

# %%
rc_image = cv2.imread("crop.jpg")
plt.imshow(utils_rotate.deskew(rc_image, 0, 1))

# %%
rc_image = cv2.imread("crop.jpg")
plt.imshow(utils_rotate.deskew(rc_image, 1, 0))

# %%
rc_image = cv2.imread("crop.jpg")
plt.imshow(utils_rotate.deskew(rc_image, 1, 1))
